# %% [markdown]
# HW3 Report:
# ===============
#
#
#
# You should also write a short report (1-2 pages) that compares the performance of the different classifiers across all the metrics for the data set used in the last assignment. Which classifier does better on which metrics? Which one runs faster? What would be your recommendation to someone who's working on the credit model?

# %% [markdown]
# classifier:
# -----
# Last assignment, I only use classifier: logistics regession.
#
# In this homework assignment, I use the classifiers: Regression, K-Nearest Neighbor, Decision Trees, Random Forests, Boosting, and Bagging.

# %% [markdown]
# Feature:
# ------------
# Compare to last time, in which I choose all variables in my model except personID, this time I use these four features 'RevolvingUtilizationOfUnsecuredLines', 'NumberOfDependent', 'age', 'NumberOfTimes90DaysLate'.
#
# features  =  ['RevolvingUtilizationOfUnsecuredLines', 'NumberOfDependents_0.0', 'NumberOfDependents_1.0',
#        'NumberOfDependents_2.0', 'NumberOfDependents_3.0',
#        'NumberOfDependents_4.0', 'NumberOfDependents_5.0',
#        'NumberOfDependents_6.0', 'NumberOfDependents_7.0',
#        'NumberOfDependents_8.0', 'NumberOfDependents_9.0',
#        'NumberOfDependents_10.0', 'NumberOfDependents_13.0',
#        'NumberOfDependents_20.0','age_dis_(-0.109, 21.8]',
#        'age_dis_(21.8, 43.6]', 'age_dis_(43.6, 65.4]', 'age_dis_(65.4, 87.2]',
#        'age_dis_(87.2, 109]', 'NumberOfTimes90DaysLate']

# %% [markdown]
# Evaluate classifier:
# ----------
# In order to identify which classifier does better on which metrics, I groupby the results.csv by different model type and different metrics.

# %%
#have a look of the whole result
import pandas as pd
results = pd.read_csv('results.csv')
results.head(10)
# Out:
#   model_type                                                clf  \
# 0         RF  RandomForestClassifier(bootstrap=True, class_w...
# 1         RF  RandomForestClassifier(bootstrap=True, class_w...
# 2         RF  RandomForestClassifier(bootstrap=True, class_w...
# 3         RF  RandomForestClassifier(bootstrap=True, class_w...
# 4         RF  RandomForestClassifier(bootstrap=True, class_w...
# 5         RF  RandomForestClassifier(bootstrap=True, class_w...
# 6         RF  RandomForestClassifier(bootstrap=True, class_w...
# 7         RF  RandomForestClassifier(bootstrap=True, class_w...
# 8         RF  RandomForestClassifier(bootstrap=True, class_w...
# 9         RF  RandomForestClassifier(bootstrap=True, class_w...
#
#                                           parameters   auc-roc    p_at_5  \
# 0  {'max_depth': 5, 'min_samples_split': 2, 'n_es...  0.721582  0.451200
# 1  {'max_depth': 5, 'min_samples_split': 2, 'n_es...  0.721577  0.451200
# 2  {'max_depth': 5, 'min_samples_split': 10, 'n_e...  0.721557  0.450667
# 3  {'max_depth': 5, 'min_samples_split': 10, 'n_e...  0.721569  0.451200
# 4  {'max_depth': 5, 'min_samples_split': 2, 'n_es...  0.721555  0.450667
# 5  {'max_depth': 5, 'min_samples_split': 2, 'n_es...  0.721576  0.451200
# 6  {'max_depth': 5, 'min_samples_split': 10, 'n_e...  0.721548  0.451200
# 7  {'max_depth': 5, 'min_samples_split': 10, 'n_e...  0.721563  0.451200
# 8  {'max_depth': 50, 'min_samples_split': 2, 'n_e...  0.720100  0.446933
# 9  {'max_depth': 50, 'min_samples_split': 2, 'n_e...  0.720536  0.447467
#
#     p_at_10   p_at_20      time
# 0  0.421333  0.210667  0.935327
# 1  0.421333  0.210667  2.106768
# 2  0.421333  0.210667  0.365906
# 3  0.421333  0.210667  2.779940
# 4  0.421333  0.210667  0.366081
# 5  0.421333  0.210667  2.273806
# 6  0.421333  0.210667  0.365095
# 7  0.421333  0.210667  1.995739
# 8  0.420267  0.210133  0.360758
# 9  0.420267  0.210133  2.128817

# %% [markdown]
# First I groupby model type, and find the best 10 model type according to AUC. The best model are random forest, decision tree and KNN model. The AUC is high in these model. The worst classifier are logistic regression and GaussianNB., which have auc-roc around 0.6

# %%
results[results.groupby(['model_type'])['auc-roc'].transform(max) == results['auc-roc']]
# Out:
#     model_type                                                clf  \
# 14          RF  RandomForestClassifier(bootstrap=True, class_w...
# 60          DT  DecisionTreeClassifier(class_weight=None, crit...
# 110        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 141         ET  ExtraTreesClassifier(bootstrap=False, class_we...
# 163         AB  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 167         GB  GradientBoostingClassifier(criterion='friedman...
# 204         LR  LogisticRegression(C=10, class_weight=None, du...
# 212         NB                            GaussianNB(priors=None)
#
#                                             parameters   auc-roc    p_at_5  \
# 14   {'max_depth': 50, 'min_samples_split': 10, 'n_...  0.721645  0.448000
# 60   {'criterion': 'entropy', 'max_features': 'sqrt...  0.721590  0.450667
# 110  {'algorithm': 'ball_tree', 'n_neighbors': 100,...  0.672314  0.449600
# 141  {'criterion': 'entropy', 'max_features': 'sqrt...  0.721713  0.451200
# 163      {'algorithm': 'SAMME.R', 'n_estimators': 100}  0.721576  0.442133
# 167  {'max_depth': 5, 'subsample': 0.5, 'n_estimato...  0.721723  0.450667
# 204                      {'C': 0.001, 'penalty': 'l1'}  0.694941  0.451200
# 212                                                 {}  0.673455  0.622400
#
#       p_at_10   p_at_20       time
# 14   0.421333  0.210667   0.503397
# 60   0.421333  0.210667   0.040772
# 110  0.456000  0.228000  67.401833
# 141  0.421333  0.210667   1.697929
# 163  0.421333  0.210667   4.137742
# 167  0.421333  0.210667   0.884544
# 204  0.647467  0.323733   0.139567
# 212  0.311200  0.155600   0.055780

# %% [markdown]
# Running times:
# ---------

# %% [markdown]
# Then lets take a look at which type of model running fast and which running slow. During function running, the KNN are really slow, take around 67.40. Decision Tree is the fastest. Random forest is a little bit slower than decision tree, but is much faster than others.

# %% [markdown]
# Recommendation:
# ------

# %% [markdown]
# For this dataset, I would use random forest and decision tree. First, because random forest and decision tree as well as KNN are best model among all. However, KNN is one of the slowest model according to its running time. Compare to that, random forest and decision tree are faster. Second, decision tree is one of the most interpretable model among all. So I will definately use RF and DT.
